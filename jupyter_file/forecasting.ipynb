# %%
import numpy as np
import pandas as pd
import glob
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading Data

# %%
path_dataset = "../dataset/PM2.5/"
# load all files
all_files = glob.glob(path_dataset + "/*.xlsx")

# %%
all_files = sorted(all_files)
all_files
# Out:
# ['../dataset/PM2.5/PM2.5(2011).xlsx',
#  '../dataset/PM2.5/PM2.5(2012).xlsx',
#  '../dataset/PM2.5/PM2.5(2013).xlsx',
#  '../dataset/PM2.5/PM2.5(2014).xlsx',
#  '../dataset/PM2.5/PM2.5(2015).xlsx',
#  '../dataset/PM2.5/PM2.5(2016).xlsx',
#  '../dataset/PM2.5/PM2.5(2017).xlsx',
#  '../dataset/PM2.5/PM2.5(2018).xlsx',
#  '../dataset/PM2.5/PM2.5(2019).xlsx',
#  '../dataset/PM2.5/PM2.5(2020).xlsx',
#  '../dataset/PM2.5/PM2.5(2021).xlsx',
#  '../dataset/PM2.5/PM2.5(2022).xlsx',
#  '../dataset/PM2.5/PM2.5(2023).xlsx']

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /opt/conda/envs/ts/lib/python3.10/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /opt/conda/envs/ts/lib/python3.10/site-packages (from openpyxl) (1.1.0)

# %%
xls = pd.ExcelFile(all_files[0])
test_df = pd.read_excel(xls, 'PM2.5')

# %%
test_df
# Out:
#                     Date                54T   36T   30T
# 0    2011-01-01 00:00:00                NaN   NaN   NaN
# 1    2011-01-02 00:00:00                NaN   NaN   NaN
# 2    2011-01-03 00:00:00                NaN   NaN   NaN
# 3    2011-01-04 00:00:00                NaN   NaN   NaN
# 4    2011-01-05 00:00:00                NaN   NaN   NaN
# ..                   ...                ...   ...   ...
# 363  2011-12-30 00:00:00                NaN  22.0  26.0
# 364  2011-12-31 00:00:00                NaN  21.0  25.0
# 365                  NaN                NaN   NaN   NaN
# 366                  NaN                NaN   NaN   NaN
# 367            หมายเหตุ   N/A : ไม่มีข้อมูล   NaN   NaN
#
# [368 rows x 4 columns]

# %% [markdown]
# # Pre-processing Data

# %%
# Create an empty dataframe for waiting for the concatenation
merged_df = pd.DataFrame(columns=['Date', '36T'])
for file_name in all_files:
    xls = pd.ExcelFile(file_name)
    df = pd.read_excel(xls, 'PM2.5', engine='openpyxl')
    # Drop every row following Date containing NaN
    df = df.dropna(subset=['Date'])
    # Keep only Date and 36T Column
    try:
        df = df[['Date', '36T']]
    except:
        df = df[['Date', '36T ']]
        # rename the column form '36T ' to '36T'
        df = df.rename(columns={'36T ': '36T'})
       
       
    # Convert Date to datetime, if some rows are not in the right format, drop them
    try:
        # Drop last row, then convert to datetime
        df = df[:-1]
        df['Date'] = pd.to_datetime(df['Date'])
    except:
        df['Date'] = pd.to_datetime(df['Date'])
       
    # Concatenate the dataframe
    merged_df = pd.concat([merged_df, df], axis=0)
# reset index
merged_df = merged_df.reset_index(drop=True)
merged_df
# Out:
# /tmp/ipykernel_28440/2132115905.py:26: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   merged_df = pd.concat([merged_df, df], axis=0)
#            Date   36T
# 0    2011-01-01   NaN
# 1    2011-01-02   NaN
# 2    2011-01-03   NaN
# 3    2011-01-04   NaN
# 4    2011-01-05   NaN
# ...         ...   ...
# 4742 2023-12-27  28.7
# 4743 2023-12-28  29.8
# 4744 2023-12-29  23.2
# 4745 2023-12-30  20.2
# 4746 2023-12-31  21.1
#
# [4747 rows x 2 columns]

# %% [markdown]
# # Manipulating Data

# %%
# Plot the data
plt.figure(figsize=(10,5))
plt.plot(merged_df['Date'], merged_df['36T'])
plt.show()

# %%
# Replace the NaN values by the mean of the column
mean_df_copy = merged_df.copy()
mean_df_copy['36T'] = mean_df_copy['36T'].fillna(mean_df_copy['36T'].mean())
plt.figure(figsize=(10,5))
plt.figure(figsize=(10,5))
plt.plot(mean_df_copy['Date'], mean_df_copy['36T'])
plt.show()

# %%
# Replace the NaN values by random values in the range 1 to the mean by each row
random_df_copy = merged_df.copy()
mean_value = random_df_copy['36T'].mean()
random_values = pd.Series(np.random.randint(1, mean_value + 1, size=len(random_df_copy)), index=random_df_copy.index)
random_df_copy['36T'] = random_df_copy['36T'].fillna(random_values)

plt.figure(figsize=(10, 5))
plt.plot(random_df_copy['Date'], random_df_copy['36T'])
plt.show()

# %%
# Replace the NaN values with range 1 to 30
random_df_copy2 = merged_df.copy()
min_ = 1
max_ = 20
random_values = pd.Series(np.random.randint(min_, max_+1, size=len(random_df_copy2)), index=random_df_copy2.index)
random_df_copy2['36T'] = random_df_copy2['36T'].fillna(random_values)

plt.figure(figsize=(10, 5))
plt.plot(random_df_copy2['Date'], random_df_copy2['36T'])
plt.show()

# %% [markdown]
# # Decomposing Data

# %%
from statsmodels.tsa.seasonal import seasonal_decompose


# Decompose the data
decomposed = seasonal_decompose(random_df_copy2['36T'], model='additive', period=365)
# Plot the decomposed components
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(10, 10))
decomposed.observed.plot(ax=ax1)
ax1.set_ylabel('Observed')
decomposed.trend.plot(ax=ax2)
ax2.set_ylabel('Trend')
decomposed.seasonal.plot(ax=ax3)
ax3.set_ylabel('Seasonal')
decomposed.resid.plot(ax=ax4)
ax4.set_ylabel('Residual')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Splitting Data

# %%
# display last rows of the dataframe
random_df_copy2.tail()
# Out:
#            Date   36T
# 4742 2023-12-27  28.7
# 4743 2023-12-28  29.8
# 4744 2023-12-29  23.2
# 4745 2023-12-30  20.2
# 4746 2023-12-31  21.1

# %%
# Split the data into train and test, by 2011-2021 being the train and 2022-2023 the test
train = random_df_copy2[random_df_copy2['Date'].dt.year < 2022]
test = random_df_copy2[random_df_copy2['Date'].dt.year >= 2022]

# %% [markdown]
# # Model Building

# %% [markdown]
# ## ARIMA Model

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# Fit the model

model = ARIMA(train['36T'])
model_fit = model.fit()

# Make predictions
predictions = model_fit.forecast(steps=len(test))
# Calculate the error
error = mean_squared_error(test['36T'], predictions)
error
# Out:
# 767.9916657290867

# %%
# predict on test then plot
plt.figure(figsize=(10,5))
plt.plot(train['Date'], train['36T'], label='Train')
plt.plot(test['Date'], test['36T'], label='Test')
plt.plot(test['Date'], predictions, label='Predictions')
plt.legend()
plt.show()

# %% [markdown]
# ## LSTM Model

# %%
train.shape, test.shape
# Out:
# ((4017, 2), (730, 2))

# %%
# # Set time lag for prediction
# This code work on correct x1, x2, x3, ... x30 to predict x31, x32, x33, ... x60
next_t = 30
 
# Training data
X_train = []
y_train = []
for i in range(len(train) - next_t):
    X_train.append(train['36T'].values[i:i+next_t])
    y_train.append(train['36T'].values[i+1:i+next_t+1])
X_train = np.array(X_train)
y_train = np.array(y_train)
 
# Testing data
X_test = []
y_test = []
for i in range(len(test) - next_t):
    X_test.append(test['36T'].values[i:i+next_t])
    y_test.append(test['36T'].values[i+1:i+next_t+1])
X_test = np.array(X_test)
y_test = np.array(y_test)
 
# reshape the data
X_train = X_train.reshape(-1, next_t, 1)
y_train = y_train.reshape(-1, next_t, 1)
X_test = X_test.reshape(-1, next_t, 1)
y_test = y_test.reshape(-1, next_t, 1)
 
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((3987, 30, 1), (3987, 30, 1), (700, 30, 1), (700, 30, 1))

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Define the model architecture
model = Sequential()
model.add(LSTM(64, input_shape=(next_t, 1), return_sequences=True))
model.add(Dense(1, activation='relu'))  # Moved activation parameter inside Dense
model.compile(optimizer='adam', loss='mse')

model.summary()
# Out:
# 2024-03-26 04:13:04.308630: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-26 04:13:04.653428: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-26 04:13:04.990667: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-26 04:13:06.039915: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /opt/conda/envs/ts/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 30, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 30, 1)          │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,961 (66.25 KB)
#  Trainable params: 16,961 (66.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fit the model
history = model.fit(X_train, y_train, epochs=200, batch_size=64, verbose=1, shuffle=False, validation_data=(X_test, y_test))
# Out:
# Epoch 1/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1211.6520 - val_loss: 1324.3702
# Epoch 2/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 964.0667 - val_loss: 1027.7810
# Epoch 3/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 739.3946 - val_loss: 908.0974
# Epoch 4/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 653.1475 - val_loss: 852.1094
# Epoch 5/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 608.5163 - val_loss: 794.4249
# Epoch 6/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 562.0355 - val_loss: 741.2073
# Epoch 7/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 521.4749 - val_loss: 701.2994
# Epoch 8/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 489.8044 - val_loss: 667.0279
# Epoch 9/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 462.3236 - val_loss: 636.5051
# Epoch 10/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 438.2111 - val_loss: 609.3372
# Epoch 11/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 416.5716 - val_loss: 584.5782
# Epoch 12/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 397.3364 - val_loss: 562.2650
# Epoch 13/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 380.0350 - val_loss: 541.8947
# Epoch 14/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 364.2779 - val_loss: 523.1997
# Epoch 15/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 349.9840 - val_loss: 506.0564
# Epoch 16/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 336.9318 - val_loss: 490.2790
# Epoch 17/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 324.9357 - val_loss: 475.5360
# Epoch 18/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 314.9292 - val_loss: 462.0449
# Epoch 19/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 303.9583 - val_loss: 449.3391
# Epoch 20/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 294.4603 - val_loss: 437.5177
# Epoch 21/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 285.8370 - val_loss: 426.3292
# Epoch 22/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 277.7423 - val_loss: 415.8773
# Epoch 23/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 270.1211 - val_loss: 406.1322
# Epoch 24/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 263.5143 - val_loss: 396.7477
# Epoch 25/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 256.6056 - val_loss: 387.9511
# Epoch 26/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 250.2761 - val_loss: 379.4122
# Epoch 27/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 244.4198 - val_loss: 371.2131
# Epoch 28/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 239.1994 - val_loss: 363.6878
# Epoch 29/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 233.7215 - val_loss: 356.3857
# Epoch 30/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 229.3075 - val_loss: 349.2485
# Epoch 31/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 224.1460 - val_loss: 342.3698
# Epoch 32/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 219.7301 - val_loss: 335.8876
# Epoch 33/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 215.5378 - val_loss: 329.4326
# Epoch 34/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 211.5223 - val_loss: 323.2545
# Epoch 35/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 207.5874 - val_loss: 317.2272
# Epoch 36/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 203.8626 - val_loss: 311.4077
# Epoch 37/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 200.2431 - val_loss: 305.7002
# Epoch 38/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 196.9131 - val_loss: 300.3677
# Epoch 39/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 193.5955 - val_loss: 295.1087
# Epoch 40/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 190.4353 - val_loss: 289.9817
# Epoch 41/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 187.4463 - val_loss: 284.9506
# Epoch 42/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 184.6311 - val_loss: 280.2136
# Epoch 43/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 181.9349 - val_loss: 275.5230
# Epoch 44/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 179.3795 - val_loss: 271.0461
# Epoch 45/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 176.9337 - val_loss: 266.7229
# Epoch 46/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 174.5759 - val_loss: 262.5677
# Epoch 47/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 172.3756 - val_loss: 258.5237
# Epoch 48/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 170.2294 - val_loss: 254.6345
# Epoch 49/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 168.2178 - val_loss: 250.8520
# Epoch 50/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 166.2272 - val_loss: 247.1874
# Epoch 51/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 164.4168 - val_loss: 243.5793
# Epoch 52/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 162.5908 - val_loss: 240.1525
# Epoch 53/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 160.8971 - val_loss: 236.7870
# Epoch 54/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 159.2208 - val_loss: 233.5728
# Epoch 55/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 157.6058 - val_loss: 230.4384
# Epoch 56/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 156.1049 - val_loss: 227.4247
# Epoch 57/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 154.6026 - val_loss: 224.4715
# Epoch 58/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 153.2340 - val_loss: 221.6738
# Epoch 59/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 151.9170 - val_loss: 218.9333
# Epoch 60/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 150.7034 - val_loss: 216.0637
# Epoch 61/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 149.3477 - val_loss: 213.4541
# Epoch 62/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 148.1483 - val_loss: 210.9258
# Epoch 63/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 146.9374 - val_loss: 208.4599
# Epoch 64/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 145.7935 - val_loss: 206.0912
# Epoch 65/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 144.6882 - val_loss: 203.7484
# Epoch 66/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 143.6474 - val_loss: 201.5318
# Epoch 67/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 142.6066 - val_loss: 199.3128
# Epoch 68/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 141.6359 - val_loss: 197.2493
# Epoch 69/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 140.6700 - val_loss: 195.1579
# Epoch 70/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 139.7738 - val_loss: 193.2247
# Epoch 71/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 138.8761 - val_loss: 191.2534
# Epoch 72/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 138.0494 - val_loss: 189.4518
# Epoch 73/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 137.2287 - val_loss: 187.5726
# Epoch 74/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 136.4332 - val_loss: 185.9019
# Epoch 75/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 135.6984 - val_loss: 184.1007
# Epoch 76/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 134.9323 - val_loss: 182.5647
# Epoch 77/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 134.2881 - val_loss: 180.8706
# Epoch 78/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 133.5640 - val_loss: 179.3901
# Epoch 79/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 132.9896 - val_loss: 177.7069
# Epoch 80/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 132.2724 - val_loss: 176.3776
# Epoch 81/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 131.7787 - val_loss: 174.8572
# Epoch 82/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 131.1741 - val_loss: 173.5090
# Epoch 83/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 130.6652 - val_loss: 172.1162
# Epoch 84/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 130.1216 - val_loss: 170.8628
# Epoch 85/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 129.6853 - val_loss: 169.5373
# Epoch 86/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 129.1066 - val_loss: 168.5428
# Epoch 87/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 128.6774 - val_loss: 167.2154
# Epoch 88/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 128.2034 - val_loss: 166.3411
# Epoch 89/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 127.8467 - val_loss: 164.9450
# Epoch 90/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 127.2747 - val_loss: 163.9485
# Epoch 91/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 126.8688 - val_loss: 163.0066
# Epoch 92/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 126.4293 - val_loss: 161.8274
# Epoch 93/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 125.9811 - val_loss: 160.9397
# Epoch 94/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 125.5975 - val_loss: 159.8789
# Epoch 95/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 125.2123 - val_loss: 159.0771
# Epoch 96/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 124.8163 - val_loss: 157.9646
# Epoch 97/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 124.4285 - val_loss: 157.3169
# Epoch 98/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 124.1223 - val_loss: 156.2932
# Epoch 99/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 123.6785 - val_loss: 155.4810
# Epoch 100/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 123.3341 - val_loss: 154.5474
# Epoch 101/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 122.9660 - val_loss: 153.8686
# Epoch 102/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 122.6469 - val_loss: 152.9654
# Epoch 103/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 122.2200 - val_loss: 152.1992
# Epoch 104/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 121.9218 - val_loss: 151.4980
# Epoch 105/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 121.5208 - val_loss: 150.7133
# Epoch 106/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 121.2345 - val_loss: 149.8748
# Epoch 107/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 120.8272 - val_loss: 149.3618
# Epoch 108/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 120.5724 - val_loss: 148.6281
# Epoch 109/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 120.1487 - val_loss: 147.9256
# Epoch 110/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 119.8896 - val_loss: 147.3179
# Epoch 111/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 119.4371 - val_loss: 146.5245
# Epoch 112/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 119.2464 - val_loss: 146.5392
# Epoch 113/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 118.9231 - val_loss: 145.8396
# Epoch 114/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 118.6838 - val_loss: 145.7831
# Epoch 115/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 118.3898 - val_loss: 144.5496
# Epoch 116/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 117.9035 - val_loss: 144.6243
# Epoch 117/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 117.8426 - val_loss: 145.0312
# Epoch 118/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 117.3384 - val_loss: 142.6030
# Epoch 119/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 117.0976 - val_loss: 142.5036
# Epoch 120/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 116.4052 - val_loss: 141.7942
# Epoch 121/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 116.1062 - val_loss: 141.0751
# Epoch 122/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 115.8180 - val_loss: 140.3563
# Epoch 123/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 115.4234 - val_loss: 139.9002
# Epoch 124/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 115.3810 - val_loss: 141.8098
# Epoch 125/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 115.2161 - val_loss: 139.0650
# Epoch 126/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 114.9977 - val_loss: 140.6987
# Epoch 127/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 114.6423 - val_loss: 137.2083
# Epoch 128/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 114.4142 - val_loss: 137.4519
# Epoch 129/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 113.9909 - val_loss: 136.7861
# Epoch 130/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 113.6603 - val_loss: 136.6515
# Epoch 131/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 113.3600 - val_loss: 136.2252
# Epoch 132/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 113.0775 - val_loss: 136.0182
# Epoch 133/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 112.7719 - val_loss: 135.5815
# Epoch 134/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 112.4978 - val_loss: 135.3482
# Epoch 135/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 112.3215 - val_loss: 135.7054
# Epoch 136/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 112.2973 - val_loss: 135.6303
# Epoch 137/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 111.9046 - val_loss: 133.5783
# Epoch 138/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 112.1555 - val_loss: 136.0321
# Epoch 139/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 113.0892 - val_loss: 134.0974
# Epoch 140/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 111.8431 - val_loss: 134.8802
# Epoch 141/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 111.4637 - val_loss: 132.2589
# Epoch 142/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 110.8412 - val_loss: 133.4868
# Epoch 143/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 110.8013 - val_loss: 131.1205
# Epoch 144/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 110.7248 - val_loss: 133.4477
# Epoch 145/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 110.0054 - val_loss: 131.8455
# Epoch 146/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 109.9046 - val_loss: 130.8443
# Epoch 147/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 109.4328 - val_loss: 132.8624
# Epoch 148/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 109.2351 - val_loss: 132.1483
# Epoch 149/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 109.1167 - val_loss: 132.2693
# Epoch 150/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 108.6320 - val_loss: 132.1491
# Epoch 151/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 108.5330 - val_loss: 131.1791
# Epoch 152/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 108.2205 - val_loss: 131.9952
# Epoch 153/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 108.5224 - val_loss: 130.9360
# Epoch 154/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 107.6492 - val_loss: 130.2576
# Epoch 155/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 107.6753 - val_loss: 129.8364
# Epoch 156/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 107.5034 - val_loss: 129.1021
# Epoch 157/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 107.0232 - val_loss: 129.5809
# Epoch 158/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 106.8887 - val_loss: 129.7191
# Epoch 159/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 106.6255 - val_loss: 128.8015
# Epoch 160/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 106.3338 - val_loss: 129.1614
# Epoch 161/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 105.8443 - val_loss: 128.4410
# Epoch 162/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 105.6891 - val_loss: 127.9216
# Epoch 163/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 105.2246 - val_loss: 127.7934
# Epoch 164/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 105.0799 - val_loss: 127.3445
# Epoch 165/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 104.6477 - val_loss: 126.7352
# Epoch 166/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 104.3911 - val_loss: 126.9372
# Epoch 167/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 104.1326 - val_loss: 127.4845
# Epoch 168/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 104.0979 - val_loss: 126.4798
# Epoch 169/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 103.7004 - val_loss: 127.4522
# Epoch 170/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 103.5440 - val_loss: 127.0996
# Epoch 171/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 103.2102 - val_loss: 126.6680
# Epoch 172/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 103.3443 - val_loss: 127.7922
# Epoch 173/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 103.4003 - val_loss: 126.5004
# Epoch 174/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 103.0168 - val_loss: 126.3850
# Epoch 175/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 102.7281 - val_loss: 126.8206
# Epoch 176/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 102.2387 - val_loss: 126.1111
# Epoch 177/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 101.9895 - val_loss: 126.1021
# Epoch 178/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 101.7274 - val_loss: 126.3877
# Epoch 179/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 101.4156 - val_loss: 125.8617
# Epoch 180/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 100.9979 - val_loss: 124.6786
# Epoch 181/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 100.9394 - val_loss: 127.1034
# Epoch 182/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 101.4943 - val_loss: 126.4980
# Epoch 183/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 100.6472 - val_loss: 124.0512
# Epoch 184/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 99.9618 - val_loss: 124.6511
# Epoch 185/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 100.2498 - val_loss: 126.1060
# Epoch 186/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 100.0235 - val_loss: 124.8863
# Epoch 187/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 99.5004 - val_loss: 123.1045
# Epoch 188/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 98.6031 - val_loss: 124.5353
# Epoch 189/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 98.6102 - val_loss: 122.7111
# Epoch 190/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 98.5597 - val_loss: 127.1987
# Epoch 191/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 98.3264 - val_loss: 122.7314
# Epoch 192/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 97.9024 - val_loss: 125.5805
# Epoch 193/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 98.3154 - val_loss: 121.1783
# Epoch 194/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 98.1366 - val_loss: 127.6675
# Epoch 195/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 97.4206 - val_loss: 121.2755
# Epoch 196/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 97.3904 - val_loss: 125.3383
# Epoch 197/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 97.7260 - val_loss: 119.5317
# Epoch 198/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 96.7369 - val_loss: 122.4321
# Epoch 199/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 96.5271 - val_loss: 121.3511
# Epoch 200/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 96.1231 - val_loss: 125.5599

# %%
# display loss
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
X_test.shape ,y_test.shape
# Out:
# ((700, 30, 1), (700, 30, 1))

# %%
# make a full prediction on the test data, then plot the result on dataframe

# %%
# make a prediction and evaluuate
y_pred = model.predict(X_test[-1].reshape(1, next_t, 1))
# reshape the data
y_pred = y_pred.reshape(-1, 1)
print(y_pred.shape)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# (30, 1)

# %%
# Last date of the test data
last_date = test['Date'].values[-1]

# Create the next 30 days date range
next_t = 30
next_t_days = pd.date_range(last_date, periods=next_t)

# Concatenate the last 30 days and the next 30 days into a new dataframe named big_df based on random_df_copy
big_df = random_df_copy.copy()
predicted_values_df = pd.DataFrame({'Date': next_t_days, '36T': None})
big_df = pd.concat([big_df, predicted_values_df], ignore_index=True)

big_df.tail()
# Out:
# /tmp/ipykernel_28440/3019929442.py:11: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   big_df = pd.concat([big_df, predicted_values_df], ignore_index=True)
#            Date  36T
# 4772 2024-01-25  NaN
# 4773 2024-01-26  NaN
# 4774 2024-01-27  NaN
# 4775 2024-01-28  NaN
# 4776 2024-01-29  NaN

# %%
import datetime
# Calculate the date 2 years ago from the current date
two_years_ago = datetime.datetime.now() - datetime.timedelta(days=365*2)

# Filter the dataframe based on the date range
filtered_df = big_df[big_df['Date'] >= two_years_ago]

# Plot the filtered dataframe
plt.figure(figsize=(10,5))
plt.plot(filtered_df['Date'], filtered_df['36T'], label='Actual')
# plot on predicted values
plt.plot(next_t_days, y_pred, label='Predictions')
plt.legend()
plt.show()
